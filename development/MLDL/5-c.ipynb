# %%
# 参考
# Pythonではじめる機械学習
import matplotlib.pyplot as plt
import pandas as pd

#　手書き数字データを読み込む
from sklearn.datasets import load_digits
digits = load_digits()
digits_df = pd.DataFrame(digits.data)

#　一部を表示
fig, axes = plt.subplots(2,5, figsize=(15,8), subplot_kw={'xticks':(), 'yticks':()})
for ax, img in zip(axes.ravel(), digits.images):
    ax.imshow(img)

digits_df.shape
# Out:
# (1797, 64)

# %%
from sklearn import decomposition

# 主成分分析（ＰＣＡ）
pca = decomposition.PCA(n_components=2)
digits_pca = pca.fit_transform(digits_df)

plt.figure(figsize = (15,15))
plt.scatter(digits_pca[:,0], digits_pca[:,1], c=digits.target)
plt.xlabel('1st principal component')
plt.ylabel('2nd principal component')
# Out:
# Text(0, 0.5, '2nd principal component')

# %%
from sklearn import manifold
tsne = manifold.TSNE()
digits_tsne = tsne.fit_transform(digits_df)

plt.figure(figsize = (15,15))
plt.scatter(digits_tsne[:,0], digits_tsne[:,1], c=digits.target)
plt.xlabel('1st principal component')
plt.ylabel('2nd principal component')
# Out:
# /Users/yugo_suzuki/Lecture/MD/.venv/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/yugo_suzuki/Lecture/MD/.venv/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# Text(0, 0.5, '2nd principal component')
